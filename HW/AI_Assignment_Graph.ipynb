# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaheer-Khan/AISem3/blob/master/HW/AI_Assignment_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# HW - 1) Implement a complete binary tree  of Depth 10 with the 5 implementations of a graph
#
# 2) Implement DFS in the binary tree to search for a node based on user input
#
# Next Class -> Please read : Constructing a Minimum Spanning Tree from a graph

# %%
"""
V = {"A", "B", "C", "D", "E", "F","G","H","I","J"}
E = {("A","B"), ("A","C"), ("A","D"), ("A","E"), ("A","F"),("A","G"),("A","H"),("A","I"),("A","J"),("B","C"),("B","D"),("B","E"),("B","F"),("B","G"),("B","H"),("B","I"),("B","J"),
     ("C","D"),("C","E"),("C","F"),("C","G"),("C","H"),("C","I"),("C","J"),("D","E"),("D","F"),("D","G"),("D","H"),("D","I"),("D","J"),("E","F"),("E","G"),("E","H"),("E","I"),("E","J"),("F","G"),("F","H"),("F","I"),("F","J"),
     ("G","H"),("G","I"),("G","J"),("H","I"),("H","J"),("I","J")} 
"""
# Out:
# '\nV = {"A", "B", "C", "D", "E", "F","G","H","I","J"}\nE = {("A","B"), ("A","C"), ("A","D"), ("A","E"), ("A","F"),("A","G"),("A","H"),("A","I"),("A","J"),("B","C"),("B","D"),("B","E"),("B","F"),("B","G"),("B","H"),("B","I"),("B","J"),\n     ("C","D"),("C","E"),("C","F"),("C","G"),("C","H"),("C","I"),("C","J"),("D","E"),("D","F"),("D","G"),("D","H"),("D","I"),("D","J"),("E","F"),("E","G"),("E","H"),("E","I"),("E","J"),("F","G"),("F","H"),("F","I"),("F","J"),\n     ("G","H"),("G","I"),("G","J"),("H","I"),("H","J"),("I","J")} \n'

# %%
# !pip install binarytree

# %% [markdown]
# 2) Graph

# %%
graph2 = [["A",["B", "C", "D", "E", "F","G","H","I","J"]],["B",["C", "D", "E", "F","G","H","I","J"]],["C",["D", "E", "F","G","H","I","J"]],["D",["E", "F","G","H","I","J"]],["E",["F","G","H","I","J"]],["F",["G","H","I","J"]],["G",["H","I","J"]],["H",["I","J"]],["I",["J"]],["J",[]]]
graph2
# Out:
# [['A', ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']],
#  ['B', ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J']],
#  ['C', ['D', 'E', 'F', 'G', 'H', 'I', 'J']],
#  ['D', ['E', 'F', 'G', 'H', 'I', 'J']],
#  ['E', ['F', 'G', 'H', 'I', 'J']],
#  ['F', ['G', 'H', 'I', 'J']],
#  ['G', ['H', 'I', 'J']],
#  ['H', ['I', 'J']],
#  ['I', ['J']],
#  ['J', []]]

# %%
path = recursive_dfs(graph2, "H")

print(" ".join(path))

# %%
type(graph2)
# Out:
# list

# %%
path = recursive_dfs(graph2, "H")

print(" ".join(path))

# %% [markdown]
# 3) Graph

# %%
graph3 = [["A",("B", "C", "D", "E", "F","G","H","I","J")],["B",("C", "D", "E", "F","G","H","I","J")],["C",("D", "E", "F","G","H","I","J")],["D",("E", "F","G","H","I","J")],["E",("F","G","H","I","J")],["F",("G","H","I","J")],["G",("H","I","J")],["H",("I","J")],["I",("J")],["J",()]]
graph3
# Out:
# [['A', ('B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['B', ('C', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['C', ('D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['D', ('E', 'F', 'G', 'H', 'I', 'J')],
#  ['E', ('F', 'G', 'H', 'I', 'J')],
#  ['F', ('G', 'H', 'I', 'J')],
#  ['G', ('H', 'I', 'J')],
#  ['H', ('I', 'J')],
#  ['I', 'J'],
#  ['J', ()]]

# %%
type(graph3)
# Out:
# list

# %%
path = recursive_dfs(graph3, "H")

print(" ".join(path))
# Out:
# H

# %% [markdown]
# 4) Graph

# %%
graph4 = (["A",("B", "C", "D", "E", "F","G","H","I","J")],["B",("C", "D", "E", "F","G","H","I","J")],["C",("D", "E", "F","G","H","I","J")],["D",("E", "F","G","H","I","J")],["E",("F","G","H","I","J")],["F",("G","H","I","J")],["G",("H","I","J")],["H",("I","J")],["I",("J")],["J",()])
graph4
# Out:
# (['A', ('B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['B', ('C', 'D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['C', ('D', 'E', 'F', 'G', 'H', 'I', 'J')],
#  ['D', ('E', 'F', 'G', 'H', 'I', 'J')],
#  ['E', ('F', 'G', 'H', 'I', 'J')],
#  ['F', ('G', 'H', 'I', 'J')],
#  ['G', ('H', 'I', 'J')],
#  ['H', ('I', 'J')],
#  ['I', 'J'],
#  ['J', ()])

# %%
type(graph4)
# Out:
# tuple

# %%
path = recursive_dfs(graph4, "H")

print(" ".join(path))
# Out:
# H

# %% [markdown]
# 5) graph

# %%
graph5 = { "A" : ["B","C","D","E","F","G","H","I","J"],
          "B" : ["C","D","E","F","G","H","I","J"],
          "C" : ["D","E","F","G","H","I","J"],
          "D" : ["E","F","G","H","I","J"],
          "E" : ["F","G","H","I","J"],
          "F" : ["G","H","I","J"],
          "G" : ["H","I","J"],
          "H" : ["I","J"],
          "J" : ["J"],
          "J": []
         }

# Print the graph 		 
graph5
# Out:
# {'A': ['B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
#  'B': ['C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
#  'C': ['D', 'E', 'F', 'G', 'H', 'I', 'J'],
#  'D': ['E', 'F', 'G', 'H', 'I', 'J'],
#  'E': ['F', 'G', 'H', 'I', 'J'],
#  'F': ['G', 'H', 'I', 'J'],
#  'G': ['H', 'I', 'J'],
#  'H': ['I', 'J'],
#  'J': []}

# %%
type(graph5)
# Out:
# dict

# %%
def recursive_dfs(graph, source,path = []):

       if source not in path:

           path.append(source)

           if source not in graph:
               # leaf node, backtrack
               return path

           for neighbour in graph[source]:

               path = recursive_dfs(graph, neighbour, path)


       return path

# %%
path = recursive_dfs(graph5, "F")

print(" ".join(path))
# Out:
# F G H I J

# %%
from binarytree import bst

my_tree = bst(height=9, is_perfect=False)

print(my_tree)
# Out:
#                                                                                                                                                                                                                                                                                                     _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________308_________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
# ...
